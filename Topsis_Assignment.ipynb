# %%
# !pip install Topsis-Charu-102303113

# %%
import pandas as pd
df = pd.read_csv("input.csv")
df
# Out:
#   Fund Name    P1    P2   P3    P4
# 0        M1  0.67  0.45  6.5  42.6
# 1        M2  0.60  0.36  3.6  53.3
# 2        M3  0.82  0.67  3.8  63.1
# 3        M4  0.76  0.58  4.8  43.0
# 4        M5  0.69  0.48  4.2  52.2
# 5        M6  0.79  0.62  5.1  49.8

# %%
from topsis_charu_102303113.topsis import topsis
topsis("input.csv", "1,1,1,1", "+,+,-,+", "output.csv")
print("✅ output.csv generated")
# Out:
# ✅ output.csv generated

# %%
out = pd.read_csv("output.csv")
out
# Out:
#   Fund Name    P1    P2   P3    P4  Topsis Score  Rank
# 0        M1  0.67  0.45  6.5  42.6      0.183355     6
# 1        M2  0.60  0.36  3.6  53.3      0.486386     5
# 2        M3  0.82  0.67  3.8  63.1      0.957789     1
# 3        M4  0.76  0.58  4.8  43.0      0.538277     4
# 4        M5  0.69  0.48  4.2  52.2      0.552637     3
# 5        M6  0.79  0.62  5.1  49.8      0.603115     2

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.bar(out.iloc[:,0], out["Topsis Score"])
plt.xlabel("Alternatives")
plt.ylabel("Topsis Score")
plt.title("TOPSIS Scores")
plt.show()
